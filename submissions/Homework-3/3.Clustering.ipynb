# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering the data from the Mayor's 24-hour hotline in Boston

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will do a clustering analysis on the 311 calls that we used in the previous homework. We will focus on choosing a value for k, clustering based on multiple features and detecting outliers.
#
# ---------------------------

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import preprocessing as preproc
from sklearn import datasets as sk_data
from sklearn.cluster import KMeans
import seaborn as sns

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv')

# %% [markdown]
# ## Step 1. Simple clustering

# %% [markdown]
# The first thing that we will try is to cluster the geolocation data of the calls. The geolocation of a record consists of a pair `(latitude, longitude)`, which represents the position of the record on the map. Since the dataset that we have spans only a small geographic location, i.e. Boston, we will use the Euclidean distance when measuring how close two points are. Techinically, we should pick a [projection](https://github.com/mbostock/d3/wiki/Geo-Projections) in order to transform the data into 2d, and measure  the Euclidean distance in the projected space.

# %% [markdown]
# Since we are dealing with numeric data, we might consider centering and normalizing them. In order to do that, check the [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler) from `scikit-learn`.

# %% [markdown]
# For exampe, the result of a clustering with 10 clusters is the following:
#
#
# ![A clustering of the locations of the calls for k=10](clusters10.png)

# %% [markdown]
# Filter the dataset to get the latitude and longitude, transform it as required and run the k-means clustering algorithm. Argue about the number of clusters you used. **(pts 50)**

# %%
#isolate columns
GEO = boston[['LONGITUDE', 'LATITUDE']]
GEO.head(10)

#fit and transform
geoFit = preproc.StandardScaler().fit(GEO)
geoFit.transform(GEO)



#kmeans error analysis

error = np.zeros(20)
error[0] = 0
for k in range (1,20):
    kmeans = KMeans(init = 'k-means++', n_clusters = k, n_init=10)
    kmeans.fit_predict(GEO)

    centroids = kmeans.cluster_centers_
    labels = kmeans.labels_
    error[k] = kmeans.inertia_
    
plt.plot(range(1,len(error)),error[1:])
plt.xlabel('Number of clusters')
plt.ylabel('Error')

# %%
#the slope of the curves steadies out around 12

kmeans = KMeans(init = 'k-means++', n_clusters = 12, n_init=10)
kmeans.fit_predict(GEO)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error[k] = kmeans.inertia_
    
print "The total error of the clustering is: ", error
print '\nCluster labels'
print labels
print '\n Cluster Centroids'
print centroids

#plot
plt.scatter(GEO.LONGITUDE, GEO.LATITUDE, c=labels)
# Out:
# The total error of the clustering is:  [     0.          93395.99999999  48237.83283109  32112.72153789
#   21165.61901673  16351.15639771  13546.51870274  11381.81511918
#    9626.60903413   7814.64055033   6838.11339747   5932.70707147
#    5280.82883904   4879.93079679   4483.62856023   4162.6938831
#    3764.64141422   3483.91946741   3180.8251611    5275.05329492]
#
# Cluster labels
# [0 6 6 ..., 1 0 1]
#
#  Cluster Centroids
# [[ 0.68444382  1.10730937]
#  [-0.21360052 -1.30621915]
#  [-0.55616391 -0.13694669]
#  [ 0.60584616 -0.98311557]
#  [-1.74605814  0.73893106]
#  [-2.05728698 -1.29331048]
#  [ 0.14903801  0.55024148]
#  [ 1.63545877  1.55587204]
#  [ 1.12635912  0.29154127]
#  [-1.09955123 -1.02404888]
#  [-1.15004116 -2.05401426]
#  [ 0.34330111 -0.34167905]]

# %% [markdown]
# -----

# %% [markdown]
# ## Step 2. Using multiple features

# %% [markdown]
# The next step in our analysis is to use more features than just the geolocation of a record (whose clustering only gives us information about the neighborhoods, which should not be a huge revelation!) Filter the dataset to get more features, transform them as required and compute another clustering. You should argue about the quality of your clustering and use domain knowledge (i.e. the fact that you are locals) to explore the clusters you produced and present them to the reader. **(pts 30)**

# %%
OTZIP1 = boston[['OnTime_Status', 'LOCATION_ZIPCODE']]

#On Time = 0, Overdue = 1
OTZP2 = OTZIP1.replace('ONTIME',0)
OTZIP = OTZP2.replace('OVERDUE',1)
OTZIP.LOCATION_ZIPCODE.value_counts



#kmeans error analysis

#error2 = np.zeros(20)
#error2[0] = 0
#for k in range (1,20):
#    kmeans2 = KMeans(init = 'k-means++', n_clusters = k, n_init=10)
#    kmeans2.fit_predict(OTZIP)

#    centroids2 = kmeans2.cluster_centers_
#    labels2 = kmeans2.labels_
#    error2[k] = kmeans2.inertia_
    
#plt.plot(range(1,len(error2)),error2[1:])
#plt.xlabel('Number of clusters')
#plt.ylabel('Error')
# Out:
# <bound method Series.value_counts of 0     2108
# 1     2215
# 2     2215
# 3     2132
# 4     2125
# 5     2125
# 6     2124
# 7     2124
# 8     2136
# 9     2122
# 10     NaN
# 11    2118
# 12    2120
# 13    2115
# 14    2132
# ...
# 46683    2130
# 46684    2129
# 46685    2115
# 46686    2108
# 46687    2135
# 46688    2118
# 46689    2126
# 46690    2124
# 46691    2126
# 46692    2125
# 46693    2130
# 46694    2131
# 46695    2126
# 46696     NaN
# 46697    2126
# Name: LOCATION_ZIPCODE, Length: 46698, dtype: float64>

# %%
boston.head(100)
# Out:
#     CASE_ENQUIRY_ID              OPEN_DT            TARGET_DT  \
# 0      101001240734  2015-01-01 00:20:09                  NaN
# 1      101001240735  2015-01-01 00:25:23  2015-01-16 08:30:00
# 2      101001240736  2015-01-01 00:25:36  2015-01-16 08:30:00
# 3      101001240740  2015-01-01 01:45:37                  NaN
# 4      101001240742  2015-01-01 02:24:59                  NaN
# 5      101001240743  2015-01-01 03:08:01                  NaN
# 6      101001240744  2015-01-01 03:35:10  2015-01-06 08:30:00
# 7      101001240746  2015-01-01 03:46:15                  NaN
# 8      101001240747  2015-01-01 04:01:30  2015-01-06 08:30:00
# 9      101001240750  2015-01-01 04:12:40                  NaN
# 10     101001240753  2015-01-01 06:31:02  2015-01-06 08:30:00
# 11     101001240754  2015-01-01 07:27:13  2015-01-31 07:27:13
# 12     101001240755  2015-01-01 08:00:18  2015-01-06 08:30:00
# 13     101001240757  2015-01-01 08:25:52  2015-01-09 08:30:00
# 14     101001240759  2015-01-01 08:35:44                  NaN
# 15     101001240760  2015-01-01 08:48:34                  NaN
# 16     101001240761  2015-01-01 08:49:13  2015-01-06 08:30:00
# 17     101001240762  2015-01-01 08:53:51  2015-01-31 08:53:51
# 18     101001240764  2015-01-01 09:12:18                  NaN
# 19     101001240765  2015-01-01 09:13:12  2015-01-05 08:30:00
# 20     101001240766  2015-01-01 09:24:41  2015-01-06 08:30:00
# 21     101001240768  2015-01-01 09:27:47  2015-01-06 08:30:00
# 22     101001240769  2015-01-01 09:28:27  2015-01-06 08:30:00
# 23     101001240770  2015-01-01 09:30:33  2015-01-06 08:30:00
# 24     101001240772  2015-01-01 09:33:25                  NaN
# 25     101001240773  2015-01-01 09:37:01  2015-01-06 08:30:00
# 26     101001240774  2015-01-01 09:39:33  2015-01-06 08:30:00
# 27     101001240775  2015-01-01 09:46:24  2015-01-06 08:30:00
# 28     101001240777  2015-01-01 09:58:14  2015-01-06 08:30:00
# 29     101001240780  2015-01-01 10:17:03  2015-01-16 08:30:00
# ..              ...                  ...                  ...
# 70     101001240832  2015-01-01 14:04:51  2015-01-06 08:30:00
# 71     101001240833  2015-01-01 14:06:35  2015-01-06 08:30:00
# 72     101001240834  2015-01-01 14:08:54  2015-01-06 08:30:00
# 73     101001240836  2015-01-01 14:18:50  2015-01-06 08:30:00
# 74     101001240837  2015-01-01 14:24:55  2015-01-31 14:24:55
# 75     101001240838  2015-01-01 14:25:24  2015-01-31 14:25:23
# 76     101001240839  2015-01-01 14:39:04  2015-01-05 08:30:00
# 77     101001240841  2015-01-01 14:44:48  2015-01-06 08:30:00
# 78     101001240842  2015-01-01 14:44:54  2015-01-31 14:44:54
# 79     101001240843  2015-01-01 14:47:34  2015-01-06 08:30:00
# 80     101001240845  2015-01-01 14:50:30                  NaN
# 81     101001240846  2015-01-01 15:03:22  2015-04-01 15:03:21
# 82     101001240847  2015-01-01 15:06:51  2015-03-10 08:30:00
# 83     101001240848  2015-01-01 15:12:23                  NaN
# 84     101001240851  2015-01-01 15:38:00                  NaN
# 85     101001240852  2015-01-01 15:48:51  2015-01-06 08:30:00
# 86     101001240853  2015-01-01 15:50:26  2015-01-06 08:30:00
# 87     101001240854  2015-01-01 16:05:04  2015-01-06 08:30:00
# 88     101001240855  2015-01-01 16:12:08                  NaN
# 89     101001240856  2015-01-01 16:15:33  2015-03-10 08:30:00
# 90     101001240859  2015-01-01 16:22:10  2015-01-06 08:30:00
# 91     101001240860  2015-01-01 16:40:40  2015-01-05 08:30:00
# 92     101001240861  2015-01-01 16:57:32  2015-03-10 08:30:00
# 93     101001240862  2015-01-01 17:00:36  2015-01-06 08:30:00
# 94     101001240863  2015-01-01 17:13:28  2015-01-31 17:13:28
# 95     101001240864  2015-01-01 17:17:34                  NaN
# 96     101001240865  2015-01-01 17:39:47  2015-01-16 08:30:00
# 97     101001240866  2015-01-01 17:44:29  2015-01-16 08:30:00
# 98     101001240869  2015-01-01 17:52:26  2015-01-05 08:30:00
# 99     101001240871  2015-01-01 18:10:59  2015-01-06 08:30:00
#
#               CLOSED_DT OnTime_Status CASE_STATUS  \
# 0   2015-01-02 09:08:42        ONTIME      Closed
# 1   2015-01-02 16:17:43        ONTIME      Closed
# 2                   NaN       OVERDUE        Open
# 3                   NaN        ONTIME        Open
# 4   2015-01-02 09:09:00        ONTIME      Closed
# 5   2015-01-02 09:09:15        ONTIME      Closed
# 6   2015-01-01 05:45:27        ONTIME      Closed
# 7                   NaN        ONTIME        Open
# 8   2015-01-01 05:06:50        ONTIME      Closed
# 9                   NaN        ONTIME        Open
# 10  2015-01-01 10:49:51        ONTIME      Closed
# 11                  NaN       OVERDUE        Open
# 12  2015-01-02 04:51:21        ONTIME      Closed
# 13                  NaN       OVERDUE        Open
# 14                  NaN        ONTIME        Open
# 15  2015-01-07 16:36:11        ONTIME      Closed
# 16  2015-01-01 11:10:00        ONTIME      Closed
# 17                  NaN       OVERDUE        Open
# 18  2015-01-05 16:37:32        ONTIME      Closed
# 19  2015-01-06 08:51:53       OVERDUE      Closed
# 20  2015-01-02 14:24:33        ONTIME      Closed
# 21  2015-01-01 10:57:46        ONTIME      Closed
# 22  2015-01-02 05:55:07        ONTIME      Closed
# 23  2015-01-02 14:18:15        ONTIME      Closed
# 24                  NaN        ONTIME        Open
# 25  2015-01-05 12:44:38        ONTIME      Closed
# 26  2015-01-05 12:44:07        ONTIME      Closed
# 27  2015-01-02 14:25:27        ONTIME      Closed
# 28  2015-01-02 06:01:16        ONTIME      Closed
# 29  2015-01-05 12:32:32        ONTIME      Closed
# ..                  ...           ...         ...
# 70  2015-01-02 12:41:11        ONTIME      Closed
# 71  2015-01-01 20:10:42        ONTIME      Closed
# 72  2015-01-01 20:10:04        ONTIME      Closed
# 73  2015-01-02 09:46:52        ONTIME      Closed
# 74  2015-01-01 14:32:32        ONTIME      Closed
# 75                  NaN       OVERDUE        Open
# 76  2015-01-01 18:13:10        ONTIME      Closed
# 77  2015-01-06 06:28:14        ONTIME      Closed
# 78                  NaN       OVERDUE        Open
# 79  2015-01-02 08:26:06        ONTIME      Closed
# 80  2015-01-08 16:36:57        ONTIME      Closed
# 81                  NaN        ONTIME        Open
# 82                  NaN        ONTIME        Open
# 83  2015-01-01 18:12:22        ONTIME      Closed
# 84  2015-01-06 16:36:34        ONTIME      Closed
# 85  2015-01-02 06:55:24        ONTIME      Closed
# 86  2015-01-06 14:51:00       OVERDUE      Closed
# 87  2015-01-02 07:47:11        ONTIME      Closed
# 88  2015-01-06 16:36:38        ONTIME      Closed
# 89                  NaN        ONTIME        Open
# 90  2015-01-01 19:33:55        ONTIME      Closed
# 91  2015-01-05 10:05:55       OVERDUE      Closed
# 92  2015-01-06 08:49:41        ONTIME      Closed
# 93  2015-01-02 07:51:05        ONTIME      Closed
# 94                  NaN       OVERDUE        Open
# 95  2015-01-09 16:35:20        ONTIME      Closed
# 96  2015-01-16 18:33:02       OVERDUE      Closed
# 97  2015-01-02 08:12:18        ONTIME      Closed
# 98  2015-01-01 19:33:56        ONTIME      Closed
# 99  2015-01-05 09:24:04        ONTIME      Closed
#
#                                        CLOSURE_REASON  \
# 0                              Case Closed Case Noted
# 1   Case Closed Duplicate of Existing Case duplica...
# 2                                                 NaN
# 3                                                 NaN
# 4                              Case Closed Case Noted
# 5                              Case Closed Case Noted
# 6              Case Closed Case Resolved clean up mva
# 7                                                 NaN
# 8      Case Closed Case Resolved clean up the  debris
# 9                                                 NaN
# 10  Case Closed Case Resolved citywide cleaned up ...
# 11                                                NaN
# 12   Case Closed Case Resolved area checked all clear
# 13                                                NaN
# 14                                                NaN
# 15                   Case Closed Bulk Item Automation
# 16                          Case Closed Case Resolved
# 17                                                NaN
# 18                   Case Closed Bulk Item Automation
# 19                          Case Closed Case Resolved
# 20          Case Closed Case Resolved potholes filled
# 21  Case Closed Case Noted During my inspection 1/...
# 22         Case Closed Case Resolved No debris found.
# 23           Case Closed Case Resolved pothole filled
# 24                                                NaN
# 25                          Case Closed Case Resolved
# 26                          Case Closed Case Resolved
# 27          Case Closed Case Resolved potholes filled
# 28  Case Closed Case Noted No items scheduled for ...
# 29   Case Closed Case Resolved Work completed 1/5/15.
# ..                                                ...
# 70  Case Closed Case Noted  Trash has been collect...
# 71            Case Closed Case Resolved Nothing found
# 72  Case Closed Case Resolved No trash or glass fo...
# 73  Case Closed Case Resolved Stickers placed at l...
# 74  Case Closed Case Invalid landlord called while...
# 75                                                NaN
# 76         Case Closed Case Resolved Animal picked up
# 77  Case Closed Case Noted  Delivered on 1/6 thank...
# 78                                                NaN
# 79  Case Closed Case Resolved deliver recycle stic...
# 80                   Case Closed Bulk Item Automation
# 81                                                NaN
# 82                                                NaN
# 83  Case Closed Case Resolved Salted will keep an ...
# 84                   Case Closed Bulk Item Automation
# 85           Case Closed Case Noted material serviced
# 86         Case Closed Case Resolved  assigned to ciu
# 87  Case Closed Case Resolved recycle pick up on ....
# 88                   Case Closed Bulk Item Automation
# 89                                                NaN
# 90  Case Closed Case Resolved Actually  82 Kendric...
# 91                     Case Closed Case Resolved done
# 92            Case Closed Case Noted have put on file
# 93                   Case Closed Case Noted delivered
# 94                                                NaN
# 95                   Case Closed Bulk Item Automation
# 96                 Case Closed Case Resolved repaired
# 97    Case Closed Duplicate of Existing Case %1240827
# 98                    Case Closed Case Resolved empty
# 99                          Case Closed Case Resolved
#
#                                         CASE_TITLE  \
# 0                                            Other
# 1                                          PRINTED
# 2                                          PRINTED
# 3                                     Animal Found
# 4                                             Fire
# 5                                             Fire
# 6                     Requests for Street Cleaning
# 7                                      Animal Lost
# 8                     Requests for Street Cleaning
# 9                                     Animal Found
# 10                    Requests for Street Cleaning
# 11                  Heat - Excessive  Insufficient
# 12                             Parking Enforcement
# 13                           Illegal Rooming House
# 14                                 Watermain Break
# 15                       Schedule Bulk Item Pickup
# 16                    Requests for Street Cleaning
# 17                  Heat - Excessive  Insufficient
# 18                     Schedule a Bulk Item Pickup
# 19                           Traffic Signal Repair
# 20                      Request for Pothole Repair
# 21                      Missed Trash: District 10B
# 22                    Requests for Street Cleaning
# 23                      Request for Pothole Repair
# 24                          Utility Casting Repair
# 25                      Request for Pothole Repair
# 26                      Request for Pothole Repair
# 27                      Request for Pothole Repair
# 28            Missed Bulk Item Pickup: District 07
# 29                                     Sign Repair
# ..                                             ...
# 70                    Requests for Street Cleaning
# 71                    Requests for Street Cleaning
# 72                    Requests for Street Cleaning
# 73                                 Sticker Request
# 74                  Heat - Excessive  Insufficient
# 75                  Heat - Excessive  Insufficient
# 76                             Pick up Dead Animal
# 77                                 Sticker Request
# 78                  Heat - Excessive  Insufficient
# 79                                 Sticker Request
# 80                     Schedule a Bulk Item Pickup
# 81             Maintenance Complaint - Residential
# 82                                Graffiti Removal
# 83  Request for Snow Plowing (Emergency Responder)
# 84                     Schedule a Bulk Item Pickup
# 85                      Missed Trash: District 10B
# 86                                 Utility Call-In
# 87                   Missed Recycling: District 04
# 88                       Schedule Bulk Item Pickup
# 89                                Graffiti Removal
# 90                    Requests for Street Cleaning
# 91     Ground Maintenance: Myrtle Street Play Area
# 92                                Graffiti Removal
# 93                                 Sticker Request
# 94                  Heat - Excessive  Insufficient
# 95                       Schedule Bulk Item Pickup
# 96                                         PRINTED
# 97                                     Sign Repair
# 98                             Empty Litter Basket
# 99                      Request for Pothole Repair
#
#                               SUBJECT                            REASON  \
# 0             Mayor's 24 Hour Hotline                      Notification
# 1             Public Works Department                     Street Lights
# 2             Public Works Department                     Street Lights
# 3                      Animal Control                     Animal Issues
# 4             Mayor's 24 Hour Hotline                      Notification
# 5             Mayor's 24 Hour Hotline                      Notification
# 6             Public Works Department                   Street Cleaning
# 7                      Animal Control                     Animal Issues
# 8             Public Works Department                   Street Cleaning
# 9                      Animal Control                     Animal Issues
# 10            Public Works Department                   Street Cleaning
# 11              Inspectional Services                           Housing
# 12  Transportation - Traffic Division  Enforcement & Abandoned Vehicles
# 13              Inspectional Services                          Building
# 14    Boston Water & Sewer Commission                      Water Issues
# 15            Public Works Department                        Sanitation
# 16            Public Works Department                   Street Cleaning
# 17              Inspectional Services                           Housing
# 18            Public Works Department                        Sanitation
# 19  Transportation - Traffic Division                   Signs & Signals
# 20            Public Works Department               Highway Maintenance
# 21            Public Works Department                        Sanitation
# 22            Public Works Department                   Street Cleaning
# 23            Public Works Department               Highway Maintenance
# 24            Public Works Department               Highway Maintenance
# 25            Public Works Department               Highway Maintenance
# 26            Public Works Department               Highway Maintenance
# 27            Public Works Department               Highway Maintenance
# 28            Public Works Department                        Sanitation
# 29  Transportation - Traffic Division                   Signs & Signals
# ..                                ...                               ...
# 70            Public Works Department                   Street Cleaning
# 71            Public Works Department                   Street Cleaning
# 72            Public Works Department                   Street Cleaning
# 73            Public Works Department                         Recycling
# 74              Inspectional Services                           Housing
# 75              Inspectional Services                           Housing
# 76            Public Works Department                   Street Cleaning
# 77            Public Works Department                         Recycling
# 78              Inspectional Services                           Housing
# 79            Public Works Department                         Recycling
# 80            Public Works Department                        Sanitation
# 81              Inspectional Services                           Housing
# 82                Property Management                          Graffiti
# 83            Public Works Department                   Street Cleaning
# 84            Public Works Department                        Sanitation
# 85            Public Works Department                        Sanitation
# 86            Public Works Department               Highway Maintenance
# 87            Public Works Department                        Sanitation
# 88            Public Works Department                        Sanitation
# 89                Property Management                          Graffiti
# 90            Public Works Department                   Street Cleaning
# 91            Public Works Department               Highway Maintenance
# 92                Property Management                          Graffiti
# 93            Public Works Department                         Recycling
# 94              Inspectional Services                           Housing
# 95            Public Works Department                        Sanitation
# 96            Public Works Department                     Street Lights
# 97  Transportation - Traffic Division                   Signs & Signals
# 98            Public Works Department               Highway Maintenance
# 99            Public Works Department               Highway Maintenance
#
#            ...          precinct land_usage  \
# 0          ...               503          E
# 1          ...               502          C
# 2          ...               502          C
# 3          ...              2010         R4
# 4          ...               708         R2
# 5          ...               709         R3
# 6          ...              1705         RC
# 7          ...              1611         R1
# 8          ...              1813          E
# 9          ...              1609         CD
# 10         ...               803        NaN
# 11         ...               802        NaN
# 12         ...              1005         R3
# 13         ...               509         R2
# 14         ...              2017          E
# 15         ...               201         CD
# 16         ...              1102         R3
# 17         ...               903         EA
# 18         ...              1101         R2
# 19         ...               308        NaN
# 20         ...               503        NaN
# 21         ...               803         R2
# 22         ...              2212         R1
# 23         ...               306          C
# 24         ...               306        NaN
# 25         ...               NaN        NaN
# 26         ...               306         CM
# 27         ...               306          E
# 28         ...              1712         R1
# 29         ...               112         R2
# ..         ...               ...        ...
# 70         ...               605          I
# 71         ...               703          A
# 72         ...               703         CM
# 73         ...               904         R1
# 74         ...              2003         R2
# 75         ...               401         RC
# 76         ...              1402         R1
# 77         ...               NaN        NaN
# 78         ...              2104          A
# 79         ...              2211         R1
# 80         ...               607         R2
# 81         ...              2104          A
# 82         ...               407          A
# 83         ...              2017        NaN
# 84         ...              2011         R2
# 85         ...              1201         R3
# 86         ...               505         R1
# 87         ...              2105         R1
# 88         ...               501         CD
# 89         ...              1004        NaN
# 90         ...              2208         R1
# 91         ...               503        NaN
# 92         ...               901         CM
# 93         ...               307         CD
# 94         ...               802         CM
# 95         ...              1106         R3
# 96         ...              1610        NaN
# 97         ...              1901         CM
# 98         ...               303         RC
# 99         ...               201        NaN
#
#                           LOCATION_STREET_NAME LOCATION_ZIPCODE Property_Type  \
# 0                                 33 Beacon St             2108       Address
# 1                           145-151 Ipswich St             2215       Address
# 2                           145-151 Ipswich St             2215       Address
# 3                           4833 Washington St             2132       Address
# 4                               10 Washburn St             2125       Address
# 5                       841-843 Dorchester Ave             2125       Address
# 6                               320 Talbot Ave             2124       Address
# 7                                 246 Minot St             2124       Address
# 8                                1137 River St             2136       Address
# 9                                 730 Adams St             2122       Address
# 10  INTERSECTION Albany St & Massachusetts Ave              NaN  Intersection
# 11                          1744 Washington St             2118       Address
# 12                               8 Cherokee St             2120       Address
# 13                              50 Hereford St             2115       Address
# 14                            95 Brook Farm Rd             2132       Address
# 15                               18 Harvard St             2129       Address
# 16                              51 Marcella St             2119       Address
# 17                                77 Camden St             2118       Address
# 18                             187 Highland St             2119       Address
# 19         INTERSECTION Chauncy St & Summer St              NaN  Intersection
# 20            INTERSECTION Beacon St & Park St              NaN  Intersection
# 21                       26 Mount Pleasant Ave             2119       Address
# 22                             81 Arlington St             2135       Address
# 23                                 4 Beacon St             2108       Address
# 24                               73 Tremont St             2108       Address
# 25                                20 Beacon St             2108       Address
# 26                                23 Beacon St             2108       Address
# 27                               88 Tremont St             2108       Address
# 28                           85 Wilmington Ave             2124       Address
# 29                          1229 Bennington St             2128       Address
# ..                                         ...              ...           ...
# 70                         653-659 E Second St             2127       Address
# 71                         423-435 E Eighth St             2127       Address
# 72                             468 E Eighth St             2127       Address
# 73                               21 Warwick St             2120       Address
# 74                     5070-5072 Washington St             2132       Address
# 75                            282 Columbus Ave             2116       Address
# 76                                53 Elmont St             2121       Address
# 77                              42 Bradford St             2118       Address
# 78                               72 Gardner St             2134       Address
# 79                             58 Cresthill Rd             2135       Address
# 80                                     58 N St             2127       Address
# 81                               72 Gardner St             2134       Address
# 82                             52 Westland Ave             2115       Address
# 83    INTERSECTION Brook Farm Rd & Lagrange St              NaN  Intersection
# 84                                 9 Oriole St             2132       Address
# 85                           58-60 Copeland St             2119       Address
# 86                         130 Mount Vernon St             2108       Address
# 87                              24 Brainerd Rd             2134       Address
# 88                               5 Appleton St             2116       Address
# 89    INTERSECTION Huntington Ave & Jamaicaway              NaN  Intersection
# 90                               72 Kenrick St             2135       Address
# 91          INTERSECTION Irving St & Myrtle St              NaN  Intersection
# 92                             437 Shawmut Ave             2118       Address
# 93                                34 Hanson St             2118       Address
# 94                           11-25 E Newton St             2118       Address
# 95                            62 Brookside Ave             2130       Address
# 96     INTERSECTION Freeport St & Southwick St              NaN  Intersection
# 97                              14 Boylston St             2130       Address
# 98                          264-266 Hanover St             2113       Address
# 99                                  32 City Sq             2129       Address
#
#    Property_ID  LATITUDE LONGITUDE                Source    Geocoded_Location
# 0        11072   42.3574  -71.0648      Constituent Call  (42.3574, -71.0648)
# 1       157262   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 2       157262   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 3       331760   42.2711  -71.1464      Constituent Call  (42.2711, -71.1464)
# 4       143386   42.3254  -71.0574      Constituent Call  (42.3254, -71.0574)
# 5        48752   42.3220  -71.0570      Constituent Call    (42.322, -71.057)
# 6       317720   42.2906  -71.0727      Constituent Call  (42.2906, -71.0727)
# 7        96119   42.2834  -71.0576      Constituent Call  (42.2834, -71.0576)
# 8       116326   42.2572  -71.1204      Constituent Call  (42.2572, -71.1204)
# 9          949   42.2847  -71.0550      Constituent Call   (42.2847, -71.055)
# 10         202   42.3335  -71.0735      Constituent Call  (42.3335, -71.0735)
# 11      351061   42.3594  -71.0587      Constituent Call  (42.3594, -71.0587)
# 12       30688   42.3303  -71.1006      Constituent Call  (42.3303, -71.1006)
# 13       73014   42.3490  -71.0856          Self Service   (42.349, -71.0856)
# 14       21939   42.2915  -71.1683      Constituent Call  (42.2915, -71.1683)
# 15       70468   42.3722  -71.0632          Self Service  (42.3722, -71.0632)
# 16       89578   42.3225  -71.0951      Constituent Call  (42.3225, -71.0951)
# 17      201313   42.3375  -71.0804      Constituent Call  (42.3375, -71.0804)
# 18       73706   42.3234  -71.0936      Constituent Call  (42.3234, -71.0936)
# 19        2848   42.3546  -71.0593      Constituent Call  (42.3546, -71.0593)
# 20        1110   42.3577  -71.0632       City Worker App  (42.3577, -71.0632)
# 21       98399   42.3274  -71.0793      Constituent Call  (42.3274, -71.0793)
# 22        4790   42.3527  -71.1555      Constituent Call  (42.3527, -71.1555)
# 23       11356   42.3579  -71.0608       City Worker App  (42.3579, -71.0608)
# 24      347781   42.3594  -71.0587       City Worker App  (42.3594, -71.0587)
# 25      348310   42.3594  -71.0587       City Worker App  (42.3594, -71.0587)
# 26      158216   42.3582  -71.0625       City Worker App  (42.3582, -71.0625)
# 27      322699   42.3575  -71.0605       City Worker App  (42.3575, -71.0605)
# 28      150462   42.2793  -71.0761      Constituent Call  (42.2793, -71.0761)
# 29       14603   42.3897  -70.9971      Constituent Call  (42.3897, -70.9971)
# ..         ...       ...       ...                   ...                  ...
# 70      124413   42.3372  -71.0370  Citizens Connect App   (42.3372, -71.037)
# 71       52153   42.3309  -71.0436  Citizens Connect App  (42.3309, -71.0436)
# 72       52199   42.3315  -71.0423  Citizens Connect App  (42.3315, -71.0423)
# 73      143363   42.3364  -71.0842          Self Service  (42.3364, -71.0842)
# 74      145574   42.2646  -71.1531      Constituent Call  (42.2646, -71.1531)
# 75      211724   42.3469  -71.0736      Constituent Call  (42.3469, -71.0736)
# 76       53389   42.2994  -71.0775      Constituent Call  (42.2994, -71.0775)
# 77      349572   42.3594  -71.0587          Self Service  (42.3594, -71.0587)
# 78      239609   42.3540  -71.1273          Self Service   (42.354, -71.1273)
# 79       44331   42.3559  -71.1583          Self Service  (42.3559, -71.1583)
# 80      100137   42.3365  -71.0311      Constituent Call  (42.3365, -71.0311)
# 81      239609   42.3540  -71.1273          Self Service   (42.354, -71.1273)
# 82      148492   42.3434  -71.0882  Citizens Connect App  (42.3434, -71.0882)
# 83        2029   42.2910  -71.1687      Constituent Call   (42.291, -71.1687)
# 84      105685   42.2809  -71.1498      Constituent Call  (42.2809, -71.1498)
# 85       42470   42.3231  -71.0798      Constituent Call  (42.3231, -71.0798)
# 86       98513   42.3576  -71.0708      Constituent Call  (42.3576, -71.0708)
# 87       19329   42.3486  -71.1310      Constituent Call   (42.3486, -71.131)
# 88        4035   42.3467  -71.0698          Self Service  (42.3467, -71.0698)
# 89        6416   42.3319  -71.1130  Citizens Connect App   (42.3319, -71.113)
# 90       81344   42.3463  -71.1658      Constituent Call  (42.3463, -71.1658)
# 91        6514   42.3593  -71.0664  Citizens Connect App  (42.3593, -71.0664)
# 92      126273   42.3397  -71.0748  Citizens Connect App  (42.3397, -71.0748)
# 93       69307   42.3439  -71.0707          Self Service  (42.3439, -71.0707)
# 94      102338   42.3382  -71.0731      Constituent Call  (42.3382, -71.0731)
# 95       22620   42.3126  -71.1038          Self Service  (42.3126, -71.1038)
# 96        5126   42.2917  -71.0481  Citizens Connect App  (42.2917, -71.0481)
# 97      162482   42.3191  -71.1107  Citizens Connect App  (42.3191, -71.1107)
# 98      155960   42.3636  -71.0549  Citizens Connect App  (42.3636, -71.0549)
# 99      163437   42.3710  -71.0627  Citizens Connect App   (42.371, -71.0627)
#
# [100 rows x 33 columns]

# %% [markdown]
# -----

# %% [markdown]
# ## Step 3. Detecting outliers

# %% [markdown]
# Now that we have a clustering of the records in the dataset, we can detect the outlying ones. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(pts 20)**

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
